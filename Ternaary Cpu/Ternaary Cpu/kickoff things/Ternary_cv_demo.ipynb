# %%
{"cells": [{"cell_type": "code", "source": ["import numpy as np\n", "def ternary_convolution(img, kernel):\n", "    output = np.zeros_like(img)\n", "    k = kernel.shape[0] // 2\n", "    for i in range(k, img.shape[0] - k):\n", "        for j in range(k, img.shape[1] - k):\n", "            region = img[i - k:i + k + 1, j - k:j + k + 1]\n", "            val = np.sum(region * kernel)\n", "            output[i, j] = np.sign(val)\n", "    return output\n", "\n", "image = np.random.randint(-1, 2, (10, 10))\n", "kernel = np.array([[1, 0, -1], [1, 0, -1], [1, 0, -1]])\n", "print(ternary_convolution(image, kernel))"]}], "metadata": {}, "nbformat": 4, "nbformat_minor": 0}
