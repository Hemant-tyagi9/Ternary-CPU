# %%
def ternary_rsa_encrypt(m, e, n):
    return pow(m, e, n)

def ternary_rsa_decrypt(c, d, n):
    return pow(c, d, n)

def ternary_modular_inverse(a, m):
    for x in range(1, m):
        if (a * x) % m == 1:
            return x
    return None
