# %%
# main/system_integration.py

from kickoff_things.Ternary_NAS import run_evolution
from kickoff_things.ternary_nlp import run_nlp_demo
from kickoff_things.ternary_cv_demo import run_cv_demo
from kickoff_things.Hardware_simulator import simulate_chip_design
from kickoff_things.Qurit_bridge_demo import run_quantum_bridge_demo
from kickoff_things.Ternary_cryptography_prototype import run_crypto_demo

def full_system_pipeline():
    print("⚙️ Starting Full Ternary System Pipeline...\n")

    print("📦 1. Simulating Ternary Hardware...")
    simulate_chip_design()

    print("🧬 2. Running Neural NAS Evolution...")
    run_evolution()

    print("📡 3. Quantum Bridge Demonstration...")
    run_quantum_bridge_demo()

    print("🔐 4. Cryptography Prototype...")
    run_crypto_demo()

    print("💬 5. Ternary NLP Demonstration...")
    run_nlp_demo()

    print("🖼️ 6. Ternary Computer Vision Demo...")
    run_cv_demo()

    print("\n✅ All modules executed successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2437148767.py in <cell line: 0>()
#       1 # main/system_integration.py
#       2
# ----> 3 from kickoff_things.Ternary_NAS import run_evolution
#       4 from kickoff_things.ternary_nlp import run_nlp_demo
#       5 from kickoff_things.ternary_cv_demo import run_cv_demo
#
# ModuleNotFoundError: No module named 'kickoff_things'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from system_integration import full_system_pipeline
full_system_pipeline()
